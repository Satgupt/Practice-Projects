# %% [markdown]
# ### Mushroom Project

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('https://raw.githubusercontent.com/dsrscientist/dataset1/master/mushrooms.csv')
data
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %%
data.isna().sum()
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %%
data.dtypes
# Out:
# class                       object
# cap-shape                   object
# cap-surface                 object
# cap-color                   object
# bruises                     object
# odor                        object
# gill-attachment             object
# gill-spacing                object
# gill-size                   object
# gill-color                  object
# stalk-shape                 object
# stalk-root                  object
# stalk-surface-above-ring    object
# stalk-surface-below-ring    object
# stalk-color-above-ring      object
# stalk-color-below-ring      object
# veil-type                   object
# veil-color                  object
# ring-number                 object
# ring-type                   object
# spore-print-color           object
# population                  object
# habitat                     object
# dtype: object

# %%
data.columns
# Out:
# Index(['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
#        'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
#        'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
#        'stalk-surface-below-ring', 'stalk-color-above-ring',
#        'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
#        'ring-type', 'spore-print-color', 'population', 'habitat'],
#       dtype='object')

# %%
for i in data.columns:
    print(i,':\n', data[i].unique(),'\n')
# Out:
# class :
#  ['p' 'e']
#
# cap-shape :
#  ['x' 'b' 's' 'f' 'k' 'c']
#
# cap-surface :
#  ['s' 'y' 'f' 'g']
#
# cap-color :
#  ['n' 'y' 'w' 'g' 'e' 'p' 'b' 'u' 'c' 'r']
#
# bruises :
#  ['t' 'f']
#
# odor :
#  ['p' 'a' 'l' 'n' 'f' 'c' 'y' 's' 'm']
#
# gill-attachment :
#  ['f' 'a']
#
# gill-spacing :
#  ['c' 'w']
#
# gill-size :
#  ['n' 'b']
#
# gill-color :
#  ['k' 'n' 'g' 'p' 'w' 'h' 'u' 'e' 'b' 'r' 'y' 'o']
#
# stalk-shape :
#  ['e' 't']
#
# stalk-root :
#  ['e' 'c' 'b' 'r' '?']
#
# stalk-surface-above-ring :
#  ['s' 'f' 'k' 'y']
#
# stalk-surface-below-ring :
#  ['s' 'f' 'y' 'k']
#
# stalk-color-above-ring :
#  ['w' 'g' 'p' 'n' 'b' 'e' 'o' 'c' 'y']
#
# stalk-color-below-ring :
#  ['w' 'p' 'g' 'b' 'n' 'e' 'y' 'o' 'c']
#
# veil-type :
#  ['p']
#
# veil-color :
#  ['w' 'n' 'o' 'y']
#
# ring-number :
#  ['o' 't' 'n']
#
# ring-type :
#  ['p' 'e' 'l' 'f' 'n']
#
# spore-print-color :
#  ['k' 'n' 'u' 'h' 'w' 'r' 'o' 'y' 'b']
#
# population :
#  ['s' 'n' 'a' 'v' 'y' 'c']
#
# habitat :
# ...

# %%
data['veil-type'].value_counts() #contains the same value 'p' in all the rows
# Out:
# p    8124
# Name: veil-type, dtype: int64

# %%
#Hence removing the column 'veil-type'

data = data.drop(columns = 'veil-type')

# %%
#Target Variable

print('Edible (e):',data['class'].value_counts()[0])
print('Poisionous (p):',data['class'].value_counts()[1])
# Out:
# Edible (e): 4208
# Poisionous (p): 3916

# %%
#Target Variable data visualization
sns.countplot(x='class',data=data)
plt.show()

# %% [markdown]
# ### EDA Visualization

# %%
ncol,nrow = 11,2
colNames = data.columns.values
print(colNames)
# Out:
# ['class' 'cap-shape' 'cap-surface' 'cap-color' 'bruises' 'odor'
#  'gill-attachment' 'gill-spacing' 'gill-size' 'gill-color' 'stalk-shape'
#  'stalk-root' 'stalk-surface-above-ring' 'stalk-surface-below-ring'
#  'stalk-color-above-ring' 'stalk-color-below-ring' 'veil-color'
#  'ring-number' 'ring-type' 'spore-print-color' 'population' 'habitat']

# %%
enum_obj = enumerate(colNames)
print(list(enum_obj))
# Out:
# [(0, 'class'), (1, 'cap-shape'), (2, 'cap-surface'), (3, 'cap-color'), (4, 'bruises'), (5, 'odor'), (6, 'gill-attachment'), (7, 'gill-spacing'), (8, 'gill-size'), (9, 'gill-color'), (10, 'stalk-shape'), (11, 'stalk-root'), (12, 'stalk-surface-above-ring'), (13, 'stalk-surface-below-ring'), (14, 'stalk-color-above-ring'), (15, 'stalk-color-below-ring'), (16, 'veil-color'), (17, 'ring-number'), (18, 'ring-type'), (19, 'spore-print-color'), (20, 'population'), (21, 'habitat')]

# %%
plt.figure(figsize = (20,40))
for index,col in enumerate(colNames):
    plt.subplot(ncol,nrow,index+1)
    if data[col].dtype == 'object':
        sns.countplot(data[col])
        plt.title(col)
      
    
plt.tight_layout()

# %%
data.columns
# Out:
# Index(['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
#        'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
#        'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
#        'stalk-surface-below-ring', 'stalk-color-above-ring',
#        'stalk-color-below-ring', 'veil-color', 'ring-number', 'ring-type',
#        'spore-print-color', 'population', 'habitat'],
#       dtype='object')

# %%
plt.figure(figsize = (12,14))

for i in data.columns:
    if i != 'class':
        print('show', i, 'data under the poisonous and the edible class')
        sns.displot(x = data['class'],hue = data[i], multiple = 'stack')
        plt.show()
#It shows how
# Out:
# show cap-shape data under the poisonous and the edible class
# show cap-surface data under the poisonous and the edible class
# show cap-color data under the poisonous and the edible class
# show bruises data under the poisonous and the edible class
# show odor data under the poisonous and the edible class
# show gill-attachment data under the poisonous and the edible class
# show gill-spacing data under the poisonous and the edible class
# show gill-size data under the poisonous and the edible class
# show gill-color data under the poisonous and the edible class
# show stalk-shape data under the poisonous and the edible class
# show stalk-root data under the poisonous and the edible class
# show stalk-surface-above-ring data under the poisonous and the edible class
# show stalk-surface-below-ring data under the poisonous and the edible class
# show stalk-color-above-ring data under the poisonous and the edible class
# ...

# %% [markdown]
# ### Aproach1

# %%
from sklearn.preprocessing import LabelEncoder
l_enc = LabelEncoder()

# %%
for i in data.columns:
    data[i] = l_enc.fit_transform(data[i])
data.head()
# Out:
#    class  cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0      1          5            2          4        1     6                1
# 1      0          5            2          9        1     0                1
# 2      0          0            2          8        1     3                1
# 3      1          5            3          8        1     6                1
# 4      0          5            2          3        0     5                1
#
#    gill-spacing  gill-size  gill-color  ...  stalk-surface-above-ring  \
# 0             0          1           4  ...                         2
# 1             0          0           4  ...                         2
# 2             0          0           5  ...                         2
# 3             0          1           5  ...                         2
# 4             1          0           4  ...                         2
#
#    stalk-surface-below-ring  stalk-color-above-ring  stalk-color-below-ring  \
# ...

# %%
data_corr = data.corr().abs() #to get the correlation values

plt.figure(figsize=(15,13))
sns.heatmap(data_corr,vmin=-1,vmax=1,annot=True,square=True,center=0,fmt='.1g',linewidth=0.02)

plt.tight_layout()

# %% [markdown]
# ### Split features and label

# %%
X = data.drop(columns = 'class')
Y = data['class']

# %% [markdown]
# ### Normalization
#   => using StandardScaler

# %%
from sklearn.preprocessing import StandardScaler

# %%
Scaler = StandardScaler()
x_scaled = Scaler.fit_transform(X)

# %% [markdown]
# ### Splitting: Test and Train

# %%
#importing libraries
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
x_train,x_test,y_train,y_test = train_test_split(x_scaled,Y,test_size = 0.22, random_state=53)

# %% [markdown]
# ## Machine Learning
# #### Model1 : Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier 

dt_c= DecisionTreeClassifier()
dt_c.fit(x_train, y_train) #training the data
# Out:
# DecisionTreeClassifier()

# %%
dt_c.score(x_train,y_train) #checking accuracy score of the trained data
# Out:
# 1.0

# %%
y1_pred_dec = dt_c.predict(x_test) #predicting the label value for the test feature using the model

# %% [markdown]
# ### Evaluating the Decision Tree Model

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,roc_curve,roc_auc_score,classification_report

# %%
confusion_matrix(y_test,y1_pred_dec)
# Out:
# array([[954,   0],
#        [  0, 834]], dtype=int64)

# %%
pd.DataFrame(confusion_matrix(y_test,y1_pred_dec),columns=['Q3','Q4'],index=['Q3','Q4'])
# Out:
#      Q3   Q4
# Q3  954    0
# Q4    0  834

# %% [markdown]
# #### Hyper Parameter Optimization
# Using GridSearchCV

# %%
grid_param = {'criterion':['gini','entropy'],
          'max_depth':range(2,10,2),
          'min_samples_leaf':range(2,10,2),
          'min_samples_split':range(2,10,2)}

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid_search = GridSearchCV(estimator=dt_c,param_grid=grid_param,cv=5,n_jobs=-1)

# %%
grid_search.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': range(2, 10, 2),
#                          'min_samples_leaf': range(2, 10, 2),
#                          'min_samples_split': range(2, 10, 2)})

# %%
best_parameters = grid_search.best_params_
best_parameters
# Out:
# {'criterion': 'gini',
#  'max_depth': 8,
#  'min_samples_leaf': 2,
#  'min_samples_split': 2}

# %%
dt_c = DecisionTreeClassifier(criterion='gini',max_depth=10,min_samples_leaf= 2,min_samples_split= 2)

# %%
dt_c.fit(x_train,y_train)
dt_c.score(x_test,y_test)
# Out:
# 1.0

# %%
y1_pred = dt_c.predict(x_test)

# %%
accuracy_score(y_test,y1_pred)
# Out:
# 1.0

# %%
print(classification_report(y_test,y1_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       954
#            1       1.00      1.00      1.00       834
#
#     accuracy                           1.00      1788
#    macro avg       1.00      1.00      1.00      1788
# weighted avg       1.00      1.00      1.00      1788

# %% [markdown]
# #### Model2: Knn Cassifier

# %%
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.neighbors import KNeighborsClassifier

# %%
knn1 = KNeighborsClassifier()

knn1.fit(x_train,y_train) #training the data
y1_pred = knn1.predict(x_test)

# %%
knn1.score(x_test,y_test)
# Out:
# 1.0

# %%
accuracy_score(y_test,y1_pred)
# Out:
# 1.0

# %% [markdown]
# ### Hyper Parameter Optimization
# Using GridSearchCV

# %%
grid_param_knn={'algorithm': ['kd_tree', 'brute'],'leaf_size': [12,14,18],'n_neighbors': [2, 3, 6, 10]}

gridsearch_knn=GridSearchCV(estimator=knn1,param_grid=grid_param_knn)

# %%
gridsearch_knn.fit(x_train,y_train)
# Out:
# GridSearchCV(estimator=KNeighborsClassifier(),
#              param_grid={'algorithm': ['kd_tree', 'brute'],
#                          'leaf_size': [12, 14, 18],
#                          'n_neighbors': [2, 3, 6, 10]})

# %%
gridsearch_knn.best_params_
# Out:
# {'algorithm': 'kd_tree', 'leaf_size': 12, 'n_neighbors': 3}

# %%
knn1 = KNeighborsClassifier(algorithm='kd_tree',leaf_size=12,n_neighbors=3)

# %%
knn1.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='kd_tree', leaf_size=12, n_neighbors=3)

# %%
y1_pred = knn1.predict(x_test)

# %%
conf_mat_knn=confusion_matrix(y_test,y1_pred)
conf_mat_knn
# Out:
# array([[954,   0],
#        [  0, 834]], dtype=int64)

# %%
print(classification_report(y_test,y1_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       954
#            1       1.00      1.00      1.00       834
#
#     accuracy                           1.00      1788
#    macro avg       1.00      1.00      1.00      1788
# weighted avg       1.00      1.00      1.00      1788

# %% [markdown]
# ### Model3: LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression

# %%
log_reg=LogisticRegression()
log_reg.fit(x_train,y_train) #training the model
# Out:
# LogisticRegression()

# %%
y1_pred_log = log_reg.predict(x_test) #predicting the test data

# %%
accuracy_score(y_test,y1_pred_log)
# Out:
# 0.95917225950783

# %%
fpr,tpr,thresholds = roc_curve(y_test,y1_pred_log)

# %%
auc=roc_auc_score(y_test,y1_pred_log)
auc
# Out:
# 0.9592514667511275

# %%
#plotting auc curve for logistic regression model
plt.plot(fpr,tpr,color='Orange',label='ROC')
plt.plot([0,1],[0,1],color='Blue',linestyle='--',label='ROC Curve (area= %0.3f)'%auc )
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operater Characteristics (ROC) Curve')
plt.legend()
plt.show()

# %% [markdown]
# ### Model4: Random Forest Classification

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rand_f1 = RandomForestClassifier(n_estimators=85, random_state=33)

# %%
rand_f1.fit(x_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=85, random_state=33)

# %%
rand_f1.score(x_test,y_test)
# Out:
# 1.0

# %%
y1_pred = rand_f1.predict(x_test)
y1_pred
# Out:
# array([1, 0, 1, ..., 0, 1, 0])

# %%
print(classification_report(y_test,y1_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       954
#            1       1.00      1.00      1.00       834
#
#     accuracy                           1.00      1788
#    macro avg       1.00      1.00      1.00      1788
# weighted avg       1.00      1.00      1.00      1788

# %% [markdown]
# ### Saving the model for future prediction:

# %%
import pickle

# %%
filename1='mushroom__model.pickle'
pickle.dump(knn1,open(filename1,'wb'))
